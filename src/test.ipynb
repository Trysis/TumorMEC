# %%
# test
import auxiliary
import models
import constantes
import datafilter

# %%
SEED = 42

OUTDIR = constantes.OUTPUT_DIR
FILEPATH = ""
CROSS_VAL = 10
PREDICT_CLASS = ""

TYPE = ["cd3"]
CONDITION = ["wt", "ki"]
SESSION = f"{TYPE}_{'-'.join(CONDITION)}_main"

# %%
data = auxiliary.read_dataframe("../data/WT-KI_CD3_IN-TUMOR_FIBER_no-none.csv")

# %%
# Mask for the studied phenotype
MASK_TYPE = np.all(data["Type"] == TYPE.upper()
MASK_COND = data["Condition"] == CONDITION.upper()

# %%
data.head()
# Out:
#   Condition                                 FileName     X     Y  \
# 0        WT  ./12c_ZF_ MAX_12c_MW137_CD3FITC_SHG.tif  1707  1025
# 1        WT  ./12c_ZF_ MAX_12c_MW137_CD3FITC_SHG.tif   787  1225
# 2        WT  ./12c_ZF_ MAX_12c_MW137_CD3FITC_SHG.tif  3987  2425
# 3        WT  ./12c_ZF_ MAX_12c_MW137_CD3FITC_SHG.tif  3987  4025
# 4        WT  ./12c_ZF_ MAX_12c_MW137_CD3FITC_SHG.tif  1507  4265
#
#    Coherency100  Energy100  MeanInt100  VarInt100  Density100  VarDensity100  \
# 0         0.012      0.054       4.791      4.612       0.017          0.017
# 1         0.044      0.026       3.239     12.340       0.070          0.065
# 2         0.018      0.014       0.260      1.844       0.002          0.002
# 3         0.073      0.021       1.331      6.167       0.005          0.005
# 4         0.200      0.005       0.234      3.282       0.010          0.009
#
#    ...  CellEcc  Cells100um  MinDist100um  MedDist100um  CellArea100um  \
# ...
